# %%
import tensorflow as tf


input = tf.keras.layers.Input((448,448,3))
s = tf.keras.layers.Lambda(lambda x:x / 255)(input)

conv1 = tf.keras.layers.Conv2D(16,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(s)
conv1 = tf.keras.layers.Dropout(0.1)(conv1)
conv1 = tf.keras.layers.Conv2D(16,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(conv1)
pool1 = tf.keras.layers.MaxPooling2D((2,2))(conv1)

conv2 = tf.keras.layers.Conv2D(32,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(pool1)
conv2 = tf.keras.layers.Dropout(0.1)(conv2)
conv2 = tf.keras.layers.Conv2D(32,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(conv2)
pool2 = tf.keras.layers.MaxPooling2D((2,2))(conv2)

conv3 = tf.keras.layers.Conv2D(64,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(pool2)
conv3 = tf.keras.layers.Dropout(0.2)(conv3)
conv3 = tf.keras.layers.Conv2D(64,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(conv3)
pool3 = tf.keras.layers.MaxPooling2D((2,2))(conv3)

conv4 = tf.keras.layers.Conv2D(128,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(pool3)
conv4 = tf.keras.layers.Dropout(0.2)(conv4)
conv4 = tf.keras.layers.Conv2D(128,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(conv4)
pool4 = tf.keras.layers.MaxPooling2D((2,2))(conv4)

conv5 = tf.keras.layers.Conv2D(256,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(pool4)
conv5 = tf.keras.layers.Dropout(0.2)(conv5)
conv5 = tf.keras.layers.Conv2D(256,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(conv5)


#upsample
up6 = tf.keras.layers.Conv2DTranspose(128,(2,2),strides=(2,2),padding='same')(conv5)
up6 = tf.keras.layers.concatenate([up6,conv4])
conv6 = tf.keras.layers.Conv2D(128,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(up6)
conv6 = tf.keras.layers.Dropout(0.2)(conv6)
conv6 = tf.keras.layers.Conv2D(128,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(conv6)

up7 = tf.keras.layers.Conv2DTranspose(64,(2,2),strides=(2,2),padding='same')(conv6)
up7 = tf.keras.layers.concatenate([up7,conv3])
conv7 = tf.keras.layers.Conv2D(64,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(up7)
conv7 = tf.keras.layers.Dropout(0.2)(conv7)
conv7 = tf.keras.layers.Conv2D(64,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(conv7)

up8 = tf.keras.layers.Conv2DTranspose(32,(2,2),strides=(2,2),padding='same')(conv7)
up8 = tf.keras.layers.concatenate([up8,conv2])
conv8 = tf.keras.layers.Conv2D(32,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(up8)
conv8 = tf.keras.layers.Dropout(0.2)(conv8)
conv8 = tf.keras.layers.Conv2D(32,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(conv8)

up9 = tf.keras.layers.Conv2DTranspose(32,(2,2),strides=(2,2),padding='same')(conv8)
up9 = tf.keras.layers.concatenate([up9,conv1])
conv9 = tf.keras.layers.Conv2D(32,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(up9)
conv9 = tf.keras.layers.Dropout(0.2)(conv9)
conv9 = tf.keras.layers.Conv2D(32,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(conv9)

output = tf.keras.layers.Conv2D(1,(1,1),activation='sigmoid')(conv9)

# %%
model = tf.keras.Model(inputs=[input],outputs=[output])
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_17 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  lambda_15 (Lambda)             (None, 224, 224, 3)  0           ['input_17[0][0]']
#
#  conv2d_180 (Conv2D)            (None, 224, 224, 16  448         ['lambda_15[0][0]']
#                                 )
#
#  dropout_85 (Dropout)           (None, 224, 224, 16  0           ['conv2d_180[0][0]']
#                                 )
#
#  conv2d_181 (Conv2D)            (None, 224, 224, 16  2320        ['dropout_85[0][0]']
#                                 )
#
#  max_pooling2d_54 (MaxPooling2D  (None, 112, 112, 16  0          ['conv2d_181[0][0]']
#  )                              )
#
#  conv2d_182 (Conv2D)            (None, 112, 112, 32  4640        ['max_pooling2d_54[0][0]']
#                                 )
#
#  dropout_86 (Dropout)           (None, 112, 112, 32  0           ['conv2d_182[0][0]']
#                                 )
#
#  conv2d_183 (Conv2D)            (None, 112, 112, 32  9248        ['dropout_86[0][0]']
#                                 )
#
#  max_pooling2d_55 (MaxPooling2D  (None, 56, 56, 32)  0           ['conv2d_183[0][0]']
#  )
#
#  conv2d_184 (Conv2D)            (None, 56, 56, 64)   18496       ['max_pooling2d_55[0][0]']
#
#  dropout_87 (Dropout)           (None, 56, 56, 64)   0           ['conv2d_184[0][0]']
#
#  conv2d_185 (Conv2D)            (None, 56, 56, 64)   36928       ['dropout_87[0][0]']
#
#  max_pooling2d_56 (MaxPooling2D  (None, 28, 28, 64)  0           ['conv2d_185[0][0]']
#  )
#
#  conv2d_186 (Conv2D)            (None, 28, 28, 128)  73856       ['max_pooling2d_56[0][0]']
#
#  dropout_88 (Dropout)           (None, 28, 28, 128)  0           ['conv2d_186[0][0]']
#
#  conv2d_187 (Conv2D)            (None, 28, 28, 128)  147584      ['dropout_88[0][0]']
#
#  max_pooling2d_57 (MaxPooling2D  (None, 14, 14, 128)  0          ['conv2d_187[0][0]']
#  )
#
#  conv2d_188 (Conv2D)            (None, 14, 14, 256)  295168      ['max_pooling2d_57[0][0]']
#
#  dropout_89 (Dropout)           (None, 14, 14, 256)  0           ['conv2d_188[0][0]']
#
#  conv2d_189 (Conv2D)            (None, 14, 14, 256)  590080      ['dropout_89[0][0]']
#
#  conv2d_transpose_23 (Conv2DTra  (None, 28, 28, 128)  131200     ['conv2d_189[0][0]']
#  nspose)
#
#  concatenate_23 (Concatenate)   (None, 28, 28, 256)  0           ['conv2d_transpose_23[0][0]',
#                                                                   'conv2d_187[0][0]']
#
#  conv2d_190 (Conv2D)            (None, 28, 28, 128)  295040      ['concatenate_23[0][0]']
#
#  dropout_90 (Dropout)           (None, 28, 28, 128)  0           ['conv2d_190[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 28, 28, 128)  147584      ['dropout_90[0][0]']
#
#  conv2d_transpose_24 (Conv2DTra  (None, 56, 56, 64)  32832       ['conv2d_191[0][0]']
#  nspose)
#
#  concatenate_24 (Concatenate)   (None, 56, 56, 128)  0           ['conv2d_transpose_24[0][0]',
#                                                                   'conv2d_185[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 56, 56, 64)   73792       ['concatenate_24[0][0]']
#
#  dropout_91 (Dropout)           (None, 56, 56, 64)   0           ['conv2d_192[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 56, 56, 64)   36928       ['dropout_91[0][0]']
#
#  conv2d_transpose_25 (Conv2DTra  (None, 112, 112, 32  8224       ['conv2d_193[0][0]']
#  nspose)                        )
#
#  concatenate_25 (Concatenate)   (None, 112, 112, 64  0           ['conv2d_transpose_25[0][0]',
#                                 )                                 'conv2d_183[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 112, 112, 32  18464       ['concatenate_25[0][0]']
#                                 )
#
#  dropout_92 (Dropout)           (None, 112, 112, 32  0           ['conv2d_194[0][0]']
#                                 )
#
#  conv2d_195 (Conv2D)            (None, 112, 112, 32  9248        ['dropout_92[0][0]']
#                                 )
#
#  conv2d_transpose_26 (Conv2DTra  (None, 224, 224, 32  4128       ['conv2d_195[0][0]']
#  nspose)                        )
#
#  concatenate_26 (Concatenate)   (None, 224, 224, 48  0           ['conv2d_transpose_26[0][0]',
#                                 )                                 'conv2d_181[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 224, 224, 32  13856       ['concatenate_26[0][0]']
#                                 )
#
#  dropout_93 (Dropout)           (None, 224, 224, 32  0           ['conv2d_196[0][0]']
#                                 )
#
#  conv2d_197 (Conv2D)            (None, 224, 224, 32  9248        ['dropout_93[0][0]']
#                                 )
#
#  conv2d_198 (Conv2D)            (None, 224, 224, 1)  33          ['conv2d_197[0][0]']
#
# ==================================================================================================
# Total params: 1,959,345
# Trainable params: 1,959,345
# Non-trainable params: 0
# __________________________________________________________________________________________________
